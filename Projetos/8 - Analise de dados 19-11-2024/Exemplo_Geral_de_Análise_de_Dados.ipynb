# %% [markdown]
# # Análise de Dados de vendas de uma empresa fictícia nos Estados Unidos
#
#
# *   Responda às questões de negócio.
# *   Utilize os conhecimentos adquiridos ao longo do curso e também as bibliotecas: numpy, pandas, matplotlib e seaborn.

# %% [markdown]
# ## Pergundas de negócio
#
#
# 1. Análise exploratória (medidas estatísticas)
# 2. Qual cidade com maior valor de venda de produtos na Categoria "Suprimentos de Escritório"?
# 3. Qual o total de vendas por data do pedido? Demonstre o resultado por meio de um gráfico de linhas.
# 4. Qual o valor total de vendas por estado? Utilize um gráfico de barras.
# 5. Quais são as 10 cidades com maior total de vendas? Utilize um gráfico de barras.
# 6. Quais as 20 cidades com menor total de vendas? Utilzie um gráfico de barras.
# 7. Qual o segmento teve o maior total de vendas? Utilize um gráfico de pizza.
# 8. Qual o total de vendas por segmento e por ano?

# %% [markdown]
# ###Preparação das bibliotecas e carregamento dos dados

# %%
import numpy as np, pandas as pd, matplotlib as plt

# %%
dataset = pd.read_excel("dataset.xlsx")

# %% [markdown]
# ###1. Análise exploratória (medidas estatísticas)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9700 entries, 0 to 9699
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Pedido     9700 non-null   object
#  1   Data_Pedido   9700 non-null   object
#  2   ID_Cliente    9700 non-null   object
#  3   Segmento      9700 non-null   object
#  4   Pais          9700 non-null   object
#  5   Cidade        9700 non-null   object
#  6   Estado        9700 non-null   object
#  7   ID_Produto    9700 non-null   object
#  8   Categoria     9700 non-null   object
#  9   SubCategoria  9700 non-null   object
#  10  Valor_Venda   9700 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 833.7+ KB

# %% [markdown]
# - Descrito:

# %%
dataset.describe()
# Out:
#         Valor_Venda
# count  9.700000e+03
# mean   8.352892e+04
# std    3.327765e+05
# min    9.900000e-01
# 25%    3.990000e+01
# 50%    3.516800e+02
# 75%    2.403600e+04
# max    1.119997e+07
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4['Valor_Venda'].plot(kind='hist', bins=20, title='Valor_Venda')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Valor_Venda'].plot(kind='line', figsize=(8, 4), title='Valor_Venda')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# - Metodo Head:

# %%
dataset.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumidor  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumidor  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporativo  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumidor  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumidor  United States
#
#             Cidade      Estado       ID_Produto               Categoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798                 Mobília
# 1        Henderson    Kentucky  FUR-CH-10000454                 Mobília
# 2      Los Angeles  California  OFF-LA-10000240  Material de Escritório
# 3  Fort Lauderdale     Florida  FUR-TA-10000577                 Mobília
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Material de Escritório
#
#             SubCategoria  Valor_Venda
# 0           Prateleiras      261.9600
# 1               Cadeiras     731.9400
# 2              Etiquetas      14.6200
# 3                  Mesas     957.5775
# 4  Pasta para documentos   22368.0000

# %% [markdown]
# - Metodo Tail:

# %%
dataset.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente    Segmento           Pais  \
# 9695  CA-2018-154116  15/12/2018   KM-16660  Consumidor  United States
# 9696  CA-2018-154116  15/12/2018   KM-16660  Consumidor  United States
# 9697  CA-2018-154116  15/12/2018   KM-16660  Consumidor  United States
# 9698  CA-2017-105291  30/10/2017   SP-20920  Consumidor  United States
# 9699  CA-2018-147032  31/07/2018   LB-16795   Doméstico  United States
#
#                Cidade      Estado       ID_Produto                 Categoria  \
# 9695        Inglewood  California  OFF-PA-10004569    Material de Escritório
# 9696        Inglewood  California  OFF-AP-10000027    Material de Escritório
# 9697        Inglewood  California  TEC-PH-10000675  Tecnologia e Informática
# 9698  San Luis Obispo  California  OFF-FA-10003059    Material de Escritório
# 9699       Wilmington    Delaware  OFF-PA-10003256    Material de Escritório
#
#             SubCategoria  Valor_Venda
# 9695               Papel        22.83
# 9696       Fragmentadora        54.32
# 9697           Telefones    196776.00
# 9698  Grampos com trilho         3.62
# 9699               Papel        11.54

# %% [markdown]
# ###2. Qual cidade com maior valor de venda de produtos na Categoria "Suprimentos de Escritório"?

# %% [markdown]
# - Filtrando:

# %%
dataset2 = dataset[dataset["Categoria"] == "Material de Escritório"]
dataset2 = dataset2.groupby('Cidade').sum()
dataset2 = dataset2.sort_values('Valor_Venda', ascending=False)
dataset2 = dataset2.head()
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Philadelphia to Chicago
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Pedido     5 non-null      object
#  1   Data_Pedido   5 non-null      object
#  2   ID_Cliente    5 non-null      object
#  3   Segmento      5 non-null      object
#  4   Pais          5 non-null      object
#  5   Estado        5 non-null      object
#  6   ID_Produto    5 non-null      object
#  7   Categoria     5 non-null      object
#  8   SubCategoria  5 non-null      object
#  9   Valor_Venda   5 non-null      float64
# dtypes: float64(1), object(9)
# memory usage: 440.0+ bytes

# %% [markdown]
# ###3. Qual o total de vendas por data do pedido? Demonstre o resultado por meio de um gráfico de linhas.

# %%
dataset3 = dataset.groupby('Data_Pedido').sum().reset_index()
dataset3.head()
dataset3.plot(x='Data_Pedido', y='Valor_Venda', kind='line').figure.set_size_inches(15,5)

# %% [markdown]
# ###4. Qual o valor total de vendas por estado? Utilize um gráfico de barras.

# %%
dataset4 = dataset.groupby('Estado').sum().reset_index()
dataset4.plot(x='Estado', y='Valor_Venda', kind='bar').figure.set_size_inches(15,5)

# %% [markdown]
# ###5. Quais são as 10 cidades com maior total de vendas? Utilize um gráfico de barras.

# %%
dataset5 = dataset.groupby('Cidade').sum().reset_index()
dataset5 = dataset5.sort_values('Valor_Venda', ascending=False)
dataset5 = dataset5.head(10)
dataset5.plot(x='Cidade', y='Valor_Venda', kind='bar').figure.set_size_inches(15,5)

# %% [markdown]
# ###6. Quais as 20 cidades com menor total de vendas? Utilzie um gráfico de barras.

# %%
dataset6 = dataset.groupby('Cidade').sum().reset_index()
dataset6 = dataset6.sort_values('Valor_Venda', ascending=True)
dataset6 = dataset6.head(20)
dataset6.plot(x='Cidade', y='Valor_Venda', kind='bar').figure.set_size_inches(15,5)

# %% [markdown]
# ###7. Qual o segmento teve o maior total de vendas? Utilize um gráfico de pizza.

# %%
from enum import auto
dataset7 = dataset.groupby('Segmento').sum().reset_index()
dataset7.plot(x='Segmento', y='Valor_Venda', kind='pie', labels=dataset7['Segmento'], autopct='%1.1f%%').figure.set_size_inches(15,5)

# %% [markdown]
# ###8. Qual o total de vendas por segmento e por ano?

# %%
dataset8 = dataset.copy()
dataset8['Data_Pedido'] = pd.to_datetime(dataset8['Data_Pedido'], format='%d/%m/%Y')
dataset8['Ano'] = dataset8['Data_Pedido'].dt.year
dataset8 = dataset8.groupby(['Segmento', 'Ano'])['Valor_Venda'].sum().reset_index()
dataset8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Segmento     12 non-null     object
#  1   Ano          12 non-null     int32
#  2   Valor_Venda  12 non-null     float64
# dtypes: float64(1), int32(1), object(1)
# memory usage: 368.0+ bytes
